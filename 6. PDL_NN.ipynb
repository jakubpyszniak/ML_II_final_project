# %% [markdown]
# <p style="font-size: 45px; text-align: center;"><b>Machine Learning in Finance II - final project</b></p>
# <p style="font-size: 35px; text-align: center;"><b>Forecasting delays in delivery time - Brazilian E-commerce</b></p>
# <p style="font-size: 20px; text-align: center;"><b>Neural Networks</b></p>
#
# Author: Jakub Pyszniak
#
# Notebook 6

# %% [markdown]
# > **Post deadline experimentation with neural networks (practice exercises)**

# %% [markdown]
# # For future consideration

# %% [markdown]
# > **Consider cleaning up the code and building a framework to collect the results of different NN set-ups**
#
# > **Add appropriate comments**

# %% [markdown]
# # Libraries

# %%
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV, KFold
from sklearn.metrics import make_scorer
from sklearn.feature_selection import SelectFromModel
from scipy import stats
import math
import time
from scipy.stats import randint, uniform, loguniform
from sklearn.metrics import mean_squared_error, r2_score, root_mean_squared_error, mean_absolute_error

# Visual set-up
pd.set_option("display.max_columns", 60)


# NN
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
# These data will be used for CV and choosing the best models
df_train = pd.read_csv("4.train_and_test/df_train.csv")

# We will use this set to test the forecasting power of our best models (final comparisons)
df_test = pd.read_csv("4.train_and_test/df_test.csv")

# Our feature ranking dataset
fr = pd.read_excel("3.feature_ranking/feature_ranking.xlsx")

# %%
df_train.info()
df_train.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73180 entries, 0 to 73179
# Data columns (total 35 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   delay_days                     73180 non-null  float64
#  1   order_item_id                  73180 non-null  int64
#  2   total_price                    73180 non-null  float64
#  3   total_freight                  73180 non-null  float64
#  4   order_value_check              73180 non-null  float64
#  5   is_payment_sequential_1        73180 non-null  int64
#  6   payment_type_boleto            73180 non-null  int64
#  7   payment_type_credit_card       73180 non-null  int64
#  8   payment_type_debit_card        73180 non-null  int64
#  9   payment_type_voucher           73180 non-null  int64
#  10  installments_boleto            73180 non-null  int64
#  11  installments_credit_card       73180 non-null  int64
#  12  installments_debit_card        73180 non-null  int64
#  13  installments_voucher           73180 non-null  int64
#  14  product_name_length            73180 non-null  float64
#  15  product_description_length     73180 non-null  float64
#  16  product_photos_qty             73180 non-null  int64
#  17  product_weight_g               73180 non-null  float64
#  18  product_length_cm              73180 non-null  float64
#  19  product_height_cm              73180 non-null  float64
#  20  product_width_cm               73180 non-null  float64
#  21  product_category_name_english  73180 non-null  int64
#  22  seller_state                   73180 non-null  int64
#  23  customer_state                 73180 non-null  int64
#  24  cust_sell_same_state           73180 non-null  int64
#  25  customer_lat                   73180 non-null  float64
#  26  customer_lng                   73180 non-null  float64
#  27  seller_lat                     73180 non-null  float64
#  28  seller_lng                     73180 non-null  float64
#  29  cust_sell_distance_km          73180 non-null  float64
#  30  order_purchase_month           73180 non-null  int64
#  31  order_delivery_month           73180 non-null  int64
#  32  order_purchase_dow             73180 non-null  int64
#  33  order_delivery_dow             73180 non-null  int64
#  34  order_estimate_dow             73180 non-null  int64
# dtypes: float64(15), int64(20)
# memory usage: 19.5 MB
#    delay_days  order_item_id  total_price  total_freight  order_value_check  \
# 0       -21.0              1        19.99          14.10              34.09
# 1        -4.0              1        72.90          19.70              92.60
# 2       -38.0              1        50.90          15.57              66.47
# 3        -8.0              1       199.90          14.23             214.13
# 4       -12.0              2        44.00          35.26              79.26
#
#    is_payment_sequential_1  payment_type_boleto  payment_type_credit_card  \
# 0                        1                    0                         1
# 1                        1                    0                         1
# 2                        1                    0                         1
# 3                        1                    0                         1
# 4                        1                    0                         1
#
#    payment_type_debit_card  payment_type_voucher  installments_boleto  \
# 0                        0                     0                    0
# 1                        0                     0                    0
# 2                        0                     0                    0
# 3                        0                     0                    0
# 4                        0                     0                    0
#
#    installments_credit_card  installments_debit_card  installments_voucher  \
# 0                         1                        0                     0
# 1                         1                        0                     0
# 2                         1                        0                     0
# 3                         5                        0                     0
# 4                         7                        0                     0
#
#    product_name_length  product_description_length  product_photos_qty  \
# 0                 48.0                       575.0                   1
# 1                 37.0                       360.0                   1
# 2                 60.0                       473.0                   1
# 3                 60.0                       233.0                   1
# 4                 58.0                      1623.0                   1
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             100.0               20.0               15.0              15.0
# 1             650.0               45.0               15.0              25.0
# 2             600.0               30.0                4.0              20.0
# 3            2600.0               41.0                8.0              36.0
# 4             200.0               26.0               10.0              22.0
#
#    product_category_name_english  seller_state  customer_state  \
# 0                             43            21              18
# 1                             67            14              25
# 2                             39            21              18
# 3                              7            21              25
# 4                              7             5              18
#
#    cust_sell_same_state  customer_lat  customer_lng  seller_lat  seller_lng  \
# 0                     0    -22.761992    -43.450873  -23.665703  -46.518082
# 1                     0    -21.679558    -49.762053  -23.179392  -50.634922
# 2                     0    -22.449744    -43.474330  -21.766477  -48.831547
# 3                     1    -23.640572    -46.570773  -22.716839  -47.657366
# 4                     0    -22.983577    -43.220723  -16.692331  -49.268016
#
#    cust_sell_distance_km  order_purchase_month  order_delivery_month  \
# 0             329.149657                     6                     6
# 1             189.372236                     8                     8
# 2             557.068979                     2                     2
# 3             151.282904                     6                     6
# 4             942.794225                     3                     3
#
#    order_purchase_dow  order_delivery_dow  order_estimate_dow
# 0                   5                   0                   0
# 1                   0                   3                   0
# 2                   3                   4                   0
# 3                   0                   2                   3
# 4                   4                   2                   0

# %%
df_test.info()
df_test.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18295 entries, 0 to 18294
# Data columns (total 35 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   delay_days                     18295 non-null  float64
#  1   order_item_id                  18295 non-null  int64
#  2   total_price                    18295 non-null  float64
#  3   total_freight                  18295 non-null  float64
#  4   order_value_check              18295 non-null  float64
#  5   is_payment_sequential_1        18295 non-null  int64
#  6   payment_type_boleto            18295 non-null  int64
#  7   payment_type_credit_card       18295 non-null  int64
#  8   payment_type_debit_card        18295 non-null  int64
#  9   payment_type_voucher           18295 non-null  int64
#  10  installments_boleto            18295 non-null  int64
#  11  installments_credit_card       18295 non-null  int64
#  12  installments_debit_card        18295 non-null  int64
#  13  installments_voucher           18295 non-null  int64
#  14  product_name_length            18295 non-null  float64
#  15  product_description_length     18295 non-null  float64
#  16  product_photos_qty             18295 non-null  int64
#  17  product_weight_g               18295 non-null  float64
#  18  product_length_cm              18295 non-null  float64
#  19  product_height_cm              18295 non-null  float64
#  20  product_width_cm               18295 non-null  float64
#  21  product_category_name_english  18295 non-null  int64
#  22  seller_state                   18295 non-null  int64
#  23  customer_state                 18295 non-null  int64
#  24  cust_sell_same_state           18295 non-null  int64
#  25  customer_lat                   18295 non-null  float64
#  26  customer_lng                   18295 non-null  float64
#  27  seller_lat                     18295 non-null  float64
#  28  seller_lng                     18295 non-null  float64
#  29  cust_sell_distance_km          18295 non-null  float64
#  30  order_purchase_month           18295 non-null  int64
#  31  order_delivery_month           18295 non-null  int64
#  32  order_purchase_dow             18295 non-null  int64
#  33  order_delivery_dow             18295 non-null  int64
#  34  order_estimate_dow             18295 non-null  int64
# dtypes: float64(15), int64(20)
# memory usage: 4.9 MB
#    delay_days  order_item_id  total_price  total_freight  order_value_check  \
# 0       -15.0              1        108.0          16.52             124.52
# 1        -2.0              1         78.0           7.80              85.80
# 2       -19.0              1        199.9          15.15             215.05
# 3       -17.0              1         69.0          19.45              88.45
# 4        -5.0              1         44.9           9.42              54.32
#
#    is_payment_sequential_1  payment_type_boleto  payment_type_credit_card  \
# 0                        1                    0                         1
# 1                        1                    0                         1
# 2                        1                    0                         1
# 3                        1                    0                         1
# 4                        1                    1                         0
#
#    payment_type_debit_card  payment_type_voucher  installments_boleto  \
# 0                        0                     0                    0
# 1                        0                     0                    0
# 2                        0                     0                    0
# 3                        0                     0                    0
# 4                        0                     0                    1
#
#    installments_credit_card  installments_debit_card  installments_voucher  \
# 0                         1                        0                     0
# 1                         2                        0                     0
# 2                         5                        0                     0
# 3                         6                        0                     0
# 4                         0                        0                     0
#
#    product_name_length  product_description_length  product_photos_qty  \
# 0                 58.0                      3006.0                   2
# 1                 59.0                       319.0                   4
# 2                 55.0                       623.0                   1
# 3                 51.0                       324.0                   1
# 4                 51.0                      1118.0                   5
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0            1000.0               53.0                8.0              18.0
# 1             250.0               16.0                2.0              20.0
# 2             337.0               16.0               13.0              13.0
# 3             900.0               42.0                8.0              37.0
# 4             400.0               18.0                8.0              14.0
#
#    product_category_name_english  seller_state  customer_state  \
# 0                             72            15              10
# 1                             72            21              25
# 2                             72            21              18
# 3                              7            21              18
# 4                             49            21              25
#
#    cust_sell_same_state  customer_lat  customer_lng  seller_lat  seller_lng  \
# 0                     0    -21.248980    -44.998179  -22.874599  -43.477731
# 1                     1    -23.657047    -46.774874  -23.651115  -46.755211
# 2                     0    -22.704280    -43.571287  -22.828655  -47.267296
# 3                     0    -22.747569    -43.488349  -21.766477  -48.831547
# 4                     1    -23.663579    -46.617176  -23.198860  -47.293346
#
#    cust_sell_distance_km  order_purchase_month  order_delivery_month  \
# 0             239.212282                     2                     2
# 1               2.108617                    11                    11
# 2             379.200398                     6                     6
# 3             560.549267                     6                     6
# 4              86.193580                     3                     3
#
#    order_purchase_dow  order_delivery_dow  order_estimate_dow
# 0                   5                   3                   4
# 1                   4                   1                   3
# 2                   3                   2                   0
# 3                   3                   0                   3
# 4                   3                   3                   1

# %%
fr.rename(columns={"Unnamed: 0": "feature"}, inplace=True)

fr = fr.sort_values(by=["boruta_rank","mi_score"], ascending=[True, False])

fr.info()
fr.head(40)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34 entries, 2 to 11
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   feature      34 non-null     object
#  1   mi_score     34 non-null     float64
#  2   boruta_rank  34 non-null     int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.1+ KB
#                           feature  mi_score  boruta_rank
# 2                   total_freight  0.071483            1
# 29           order_purchase_month  0.067143            1
# 30           order_delivery_month  0.063950            1
# 27                     seller_lng  0.057679            1
# 28          cust_sell_distance_km  0.052569            1
# 24                   customer_lat  0.046624            1
# 25                   customer_lng  0.044898            1
# 23           cust_sell_same_state  0.043066            1
# 21                   seller_state  0.020188            1
# 13            product_name_length  0.003299            1
# 19               product_width_cm  0.003262            2
# 33             order_estimate_dow  0.157460            3
# 16               product_weight_g  0.013727            3
# 26                     seller_lat  0.057253            5
# 18              product_height_cm  0.003029            5
# 3               order_value_check  0.046281            6
# 22                 customer_state  0.040146            7
# 14     product_description_length  0.020623            9
# 1                     total_price  0.016029            9
# 32             order_delivery_dow  0.329021           10
# 20  product_category_name_english  0.007187           11
# 31             order_purchase_dow  0.002921           13
# 17              product_length_cm  0.001827           13
# 10       installments_credit_card  0.002835           14
# 15             product_photos_qty  0.001014           15
# 6        payment_type_credit_card  0.000000           16
# 9             installments_boleto  0.005858           18
# 5             payment_type_boleto  0.002510           18
# 12           installments_voucher  0.004598           19
# 4         is_payment_sequential_1  0.000000           21
# 8            payment_type_voucher  0.000000           21
# 7         payment_type_debit_card  0.001728           23
# 0                   order_item_id  0.000000           23
# 11        installments_debit_card  0.000000           23

# %%
fr = fr.set_index("feature")

# %%
br10_feat = fr.iloc[0:10].index.tolist()
print("10 best:\n", br10_feat)

br15_feat = fr.iloc[0:15].index.tolist()
print("15 best:\n", br15_feat)

br20_feat = fr.iloc[0:20].index.tolist()
print("20 best:\n", br20_feat)

br25_feat = fr.iloc[0:25].index.tolist()
print("25 best:\n", br25_feat)

br30_feat = fr.iloc[0:30].index.tolist()
print("30 best:\n", br30_feat)
# Out:
# 10 best:
#  ['total_freight', 'order_purchase_month', 'order_delivery_month', 'seller_lng', 'cust_sell_distance_km', 'customer_lat', 'customer_lng', 'cust_sell_same_state', 'seller_state', 'product_name_length']
# 15 best:
#  ['total_freight', 'order_purchase_month', 'order_delivery_month', 'seller_lng', 'cust_sell_distance_km', 'customer_lat', 'customer_lng', 'cust_sell_same_state', 'seller_state', 'product_name_length', 'product_width_cm', 'order_estimate_dow', 'product_weight_g', 'seller_lat', 'product_height_cm']
# 20 best:
#  ['total_freight', 'order_purchase_month', 'order_delivery_month', 'seller_lng', 'cust_sell_distance_km', 'customer_lat', 'customer_lng', 'cust_sell_same_state', 'seller_state', 'product_name_length', 'product_width_cm', 'order_estimate_dow', 'product_weight_g', 'seller_lat', 'product_height_cm', 'order_value_check', 'customer_state', 'product_description_length', 'total_price', 'order_delivery_dow']
# 25 best:
#  ['total_freight', 'order_purchase_month', 'order_delivery_month', 'seller_lng', 'cust_sell_distance_km', 'customer_lat', 'customer_lng', 'cust_sell_same_state', 'seller_state', 'product_name_length', 'product_width_cm', 'order_estimate_dow', 'product_weight_g', 'seller_lat', 'product_height_cm', 'order_value_check', 'customer_state', 'product_description_length', 'total_price', 'order_delivery_dow', 'product_category_name_english', 'order_purchase_dow', 'product_length_cm', 'installments_credit_card', 'product_photos_qty']
# 30 best:
#  ['total_freight', 'order_purchase_month', 'order_delivery_month', 'seller_lng', 'cust_sell_distance_km', 'customer_lat', 'customer_lng', 'cust_sell_same_state', 'seller_state', 'product_name_length', 'product_width_cm', 'order_estimate_dow', 'product_weight_g', 'seller_lat', 'product_height_cm', 'order_value_check', 'customer_state', 'product_description_length', 'total_price', 'order_delivery_dow', 'product_category_name_english', 'order_purchase_dow', 'product_length_cm', 'installments_credit_card', 'product_photos_qty', 'payment_type_credit_card', 'installments_boleto', 'payment_type_boleto', 'installments_voucher', 'is_payment_sequential_1']

# %%
# build X / y splits using only the selected features

X_train  = df_train.loc[:, df_train.columns !="delay_days"].copy()
X10_train = df_train.loc[:, br10_feat].copy()
X15_train = df_train.loc[:, br15_feat].copy()
X20_train = df_train.loc[:, br20_feat].copy()
X25_train = df_train.loc[:, br25_feat].copy()
X30_train = df_train.loc[:, br30_feat].copy()
y_train = df_train.loc[:, "delay_days"].copy()

X_test  = df_test.loc[:, df_test.columns !="delay_days"].copy()
X10_test  = df_test.loc[:, br10_feat].copy()
X15_test  = df_test.loc[:, br15_feat].copy()
X20_test  = df_test.loc[:, br20_feat].copy()
X25_test  = df_test.loc[:, br25_feat].copy()
X30_test  = df_test.loc[:, br30_feat].copy()
y_test  = df_test.loc[:, "delay_days"].copy()

# %% [markdown]
# # Let's start with just 10 features

# %%
X_test.nunique()
# Out:
# order_item_id                        8
# total_price                       2952
# total_freight                     3840
# order_value_check                10651
# is_payment_sequential_1              2
# payment_type_boleto                  2
# payment_type_credit_card             2
# payment_type_debit_card              2
# payment_type_voucher                 2
# installments_boleto                  2
# installments_credit_card            19
# installments_debit_card              2
# installments_voucher                 2
# product_name_length                 59
# product_description_length        2224
# product_photos_qty                  18
# product_weight_g                  1271
# product_length_cm                   96
# product_height_cm                   97
# product_width_cm                    85
# product_category_name_english       70
# seller_state                        20
# customer_state                      27
# cust_sell_same_state                 2
# customer_lat                      8344
# customer_lng                      8344
# seller_lat                        1522
# seller_lng                        1522
# cust_sell_distance_km            17995
# order_purchase_month                12
# order_delivery_month                12
# order_purchase_dow                   7
# order_delivery_dow                   7
# order_estimate_dow                   5
# dtype: int64

# %%
# ============================================================
# 1) Define which columns are categorical vs numeric
# ============================================================
# These are your categorical columns (from your boosting setup).
# We will NOT one-hot encode them. Instead we:
#   - map each category to an integer id
#   - feed those ids into an Embedding layer

cat_cols = [
    "order_purchase_month", "order_delivery_month", "seller_state" , "order_estimate_dow",
    "customer_state", "order_delivery_dow", "product_category_name_english", "order_purchase_dow",
    "order_delivery_dow", "order_estimate_dow"
]


##--- One variable to switch between feature sets
FEATURE_SET = 10  # <- change this to 34, 25, 20, 15

X_sets = {
    10: (X10_train, X10_test),
    15: (X15_train, X15_test),
    20: (X20_train, X20_test),
    25: (X25_train, X25_test),
    30: (X30_train, X30_test),
    34: (X_train, X_test),
}

Xn_train, Xn_test = X_sets[FEATURE_SET]
##---

# keep only the ones that actually exist in X10_train
cat_cols = [c for c in cat_cols if c in Xn_train.columns]

# Everything else (remaining columns) we treat as numeric.
# Numeric features should be standardized for neural nets.
num_cols = [c for c in Xn_train.columns if c not in cat_cols]

# %%
# ============================================================
# 2) Copy train/test to avoid altering original data
# ============================================================
# It's good practice not to mutate your original dataframes.
Xtr_n = Xn_train.copy()
Xte_n = Xn_test.copy()

# Make sure y is a NumPy array of shape (n, 1) for Keras regression.
ytr = np.asarray(y_train).reshape(-1, 1).astype("float32")
yte = np.asarray(y_test).reshape(-1, 1).astype("float32")

# %%
# ============================================================
# 3) Scale numeric features
# ============================================================
# Neural nets are sensitive to feature scale.
# If one numeric feature ranges 0..100000 and another is 0..1,
# the big one dominates gradients and training becomes unstable.

# StandardScaler transforms each numeric column to:
#   (x - mean) / std
scaler_x = StandardScaler()

# Fit scaler ONLY on training numeric features (avoid leakage!)
Xtr_num = scaler_x.fit_transform(Xtr_n[num_cols])

# Use the SAME scaler for the test set
Xte_num = scaler_x.transform(Xte_n[num_cols])

# %%
# ============================================================
# 4) Encode categorical features into integer ids
# ============================================================
# Embedding layers require integer indices (0, 1, 2, ...).
#
# We create a per-column vocabulary from TRAIN ONLY.
# Anything unseen in test will be mapped to an "unknown" id.
#
# Example:
#   seller_state vocab = ["SP","RJ","MG",...]
#   "SP" -> 0, "RJ" -> 1, "MG" -> 2, ...
#   unseen in test -> unk_id (last index)
cat_maps = {}   # will store vocabularies (categories) for each column
Xtr_cat = {}    # will store integer arrays for train
Xte_cat = {}    # will store integer arrays for test

for col in cat_cols:
    # Convert to string and fill missing values:
    # - Embeddings don't handle NaN directly.
    # - We turn missing into a literal category "NA".
    tr_vals = Xtr_n[col].astype(str).fillna("NA")
    te_vals = Xte_n[col].astype(str).fillna("NA")

    # Vocabulary: unique categories in TRAIN ONLY
    vocab = pd.Index(tr_vals.unique())
    cat_maps[col] = vocab  # save it for later (and for inference)

    # get_indexer maps each value to its index in vocab
    # if something is not found, it returns -1
    tr_ids = vocab.get_indexer(tr_vals)
    te_ids = vocab.get_indexer(te_vals)

    # Unknown category id (one beyond last known id)
    unk_id = len(vocab)

    # Replace unseen test categories (-1) with unk_id
    te_ids = np.where(te_ids == -1, unk_id, te_ids)

    # Store as int32 (Keras Embedding expects int32/int64 indices)
    Xtr_cat[col] = tr_ids.astype("int32")
    Xte_cat[col] = te_ids.astype("int32")

# %%
# ============================================================
# 5) Build the Keras model: numeric input + embedding inputs
# ============================================================
# We create:
# - one Input() for the numeric matrix
# - one Input() per categorical column (shape=(1,))
# - each categorical input goes through an Embedding layer
# - concatenate everything and pass through Dense layers (MLP)
#
# Output is one scalar prediction: regression.
num_in = keras.Input(shape=(Xtr_num.shape[1],), name="num")

cat_inputs = []  # list of Keras inputs for categorical columns
cat_embeds = []  # list of embedding outputs

for col in cat_cols:
    # vocab_size: number of training categories + 1 for unknown bucket
    vocab_size = len(cat_maps[col]) + 1

    # Embedding dimension heuristic:
    # - Small vocab -> small embedding
    # - Large vocab -> bigger embedding (capped)
    # The formula below is a simple "rule of thumb".
    emb_dim = int(min(50, round((vocab_size ** 0.25) * 4)))

    # Each categorical column is a single integer per row => shape=(1,)
    inp = keras.Input(shape=(1,), dtype="int32", name=col)

    # Embedding layer turns an integer id into a dense vector (length emb_dim)
    emb = layers.Embedding(
        input_dim=vocab_size,
        output_dim=emb_dim,
        name=f"emb_{col}"
    )(inp)

    # Embedding output shape is (batch, 1, emb_dim)
    # We reshape to (batch, emb_dim) so we can concatenate later
    emb = layers.Reshape((emb_dim,))(emb)

    cat_inputs.append(inp)
    cat_embeds.append(emb)

# Concatenate numeric + all embeddings into one big feature vector
x = layers.Concatenate(name="concat_features")([num_in] + cat_embeds)

# %%
# ============================================================
# 6) MLP "head" (dense layers)
# ============================================================
# This is the actual neural network doing the regression.
# - Dense layers learn nonlinear combinations of features.
# - Dropout helps reduce overfitting (randomly zeroes activations during training).
x = layers.Dense(256, activation="relu", name="dense_256")(x)
x = layers.Dropout(0.2, name="dropout_0p2")(x)

x = layers.Dense(128, activation="relu", name="dense_128")(x)
x = layers.Dropout(0.1, name="dropout_0p1")(x)

x = layers.Dense(64, activation="relu", name="dense_64")(x)

# Final output: single scalar regression value
out = layers.Dense(1, name="y")(x)

# Build model object
model = keras.Model(inputs=[num_in] + cat_inputs, outputs=out, name="tabular_embedding_mlp")

# %%
# ============================================================
# 7) Compile the model (optimizer, loss, metrics)
# ============================================================
# Loss:
# - MSE is standard for regression
# Metric:
# - RMSE is easier to interpret (same units as target)
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    loss="mse",
    metrics=[keras.metrics.RootMeanSquaredError(name="rmse")]
)

# Print model architecture
model.summary()
# Out:
# Model: "tabular_embedding_mlp"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ order_purchase_mon… │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ order_delivery_mon… │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ seller_state        │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ emb_order_purchase… │ (None, 1, 8)      │        104 │ order_purchase_m… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ emb_order_delivery… │ (None, 1, 8)      │        104 │ order_delivery_m… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ emb_seller_state    │ (None, 1, 9)      │        207 │ seller_state[0][… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ num (InputLayer)    │ (None, 7)         │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 8)         │          0 │ emb_order_purcha… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 8)         │          0 │ emb_order_delive… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_2 (Reshape) │ (None, 9)         │          0 │ emb_seller_state… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concat_features     │ (None, 32)        │          0 │ num[0][0],        │
# │ (Concatenate)       │                   │            │ reshape[0][0],    │
# │                     │                   │            │ reshape_1[0][0],  │
# │                     │                   │            │ reshape_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_256 (Dense)   │ (None, 256)       │      8,448 │ concat_features[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_0p2         │ (None, 256)       │          0 │ dense_256[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_128 (Dense)   │ (None, 128)       │     32,896 │ dropout_0p2[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_0p1         │ (None, 128)       │          0 │ dense_128[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_64 (Dense)    │ (None, 64)        │      8,256 │ dropout_0p1[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y (Dense)           │ (None, 1)         │         65 │ dense_64[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 50,080 (195.62 KB)
#  Trainable params: 50,080 (195.62 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# ============================================================
# 8) Prepare inputs in the format Keras expects
# ============================================================
# Keras will match dict keys to Input layer names.
# We create a dictionary like:
#   {"num": X_numeric_matrix,
#    "seller_state": int_ids,
#    "customer_state": int_ids, ...}
train_inputs = {"num": Xtr_num}
test_inputs  = {"num": Xte_num}

for col in cat_cols:
    train_inputs[col] = Xtr_cat[col]
    test_inputs[col]  = Xte_cat[col]

# %%
# ============================================================
# 9) Callbacks for stable training
# ============================================================
# EarlyStopping:
# - if validation RMSE stops improving for patience epochs, stop training
# - restore best weights so we keep the best-performing epoch
#
# ReduceLROnPlateau:
# - if learning stalls, reduce learning rate to fine-tune further
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_rmse",
        patience=10,
        restore_best_weights=True
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_rmse",
        patience=5,
        factor=0.5,
        min_lr=1e-5
    )
]

# %%
# ============================================================
# 10) Train the model
# ============================================================
# validation_split=0.1 means:
# - Keras will take 10% of the training data as validation
# - it will NOT touch X_test during training
#
# batch_size:
# - bigger batches often work well for tabular
# - 1024 is a reasonable starting point for ~90k rows
history = model.fit(
    train_inputs, ytr,
    validation_split=0.1,
    epochs=200,
    batch_size=1024,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 129.8064 - rmse: 11.3933 - val_loss: 92.5869 - val_rmse: 9.6222 - learning_rate: 0.0010
# Epoch 2/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 94.1507 - rmse: 9.7031 - val_loss: 90.3333 - val_rmse: 9.5044 - learning_rate: 0.0010
# Epoch 3/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 92.1830 - rmse: 9.6012 - val_loss: 89.0299 - val_rmse: 9.4356 - learning_rate: 0.0010
# Epoch 4/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 90.6775 - rmse: 9.5225 - val_loss: 87.5411 - val_rmse: 9.3563 - learning_rate: 0.0010
# Epoch 5/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 88.6339 - rmse: 9.4146 - val_loss: 85.1855 - val_rmse: 9.2296 - learning_rate: 0.0010
# Epoch 6/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 86.2727 - rmse: 9.2883 - val_loss: 82.6799 - val_rmse: 9.0928 - learning_rate: 0.0010
# Epoch 7/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 83.7643 - rmse: 9.1523 - val_loss: 79.9205 - val_rmse: 8.9398 - learning_rate: 0.0010
# Epoch 8/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 81.2291 - rmse: 9.0127 - val_loss: 77.0405 - val_rmse: 8.7773 - learning_rate: 0.0010
# Epoch 9/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 78.0008 - rmse: 8.8318 - val_loss: 74.1099 - val_rmse: 8.6087 - learning_rate: 0.0010
# Epoch 10/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 76.0591 - rmse: 8.7212 - val_loss: 73.0823 - val_rmse: 8.5488 - learning_rate: 0.0010
# Epoch 11/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 74.4614 - rmse: 8.6291 - val_loss: 70.7271 - val_rmse: 8.4099 - learning_rate: 0.0010
# Epoch 12/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 72.7702 - rmse: 8.5305 - val_loss: 69.2572 - val_rmse: 8.3221 - learning_rate: 0.0010
# Epoch 13/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 70.6322 - rmse: 8.4043 - val_loss: 67.1645 - val_rmse: 8.1954 - learning_rate: 0.0010
# Epoch 14/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 68.9197 - rmse: 8.3018 - val_loss: 65.8620 - val_rmse: 8.1155 - learning_rate: 0.0010
# Epoch 15/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 66.7800 - rmse: 8.1719 - val_loss: 64.5927 - val_rmse: 8.0370 - learning_rate: 0.0010
# Epoch 16/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 65.4603 - rmse: 8.0908 - val_loss: 63.7877 - val_rmse: 7.9867 - learning_rate: 0.0010
# Epoch 17/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 64.5245 - rmse: 8.0327 - val_loss: 63.3008 - val_rmse: 7.9562 - learning_rate: 0.0010
# Epoch 18/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 64.3618 - rmse: 8.0226 - val_loss: 64.1368 - val_rmse: 8.0085 - learning_rate: 0.0010
# Epoch 19/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 63.5053 - rmse: 7.9690 - val_loss: 61.7484 - val_rmse: 7.8580 - learning_rate: 0.0010
# Epoch 20/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 62.7546 - rmse: 7.9218 - val_loss: 61.5317 - val_rmse: 7.8442 - learning_rate: 0.0010
# Epoch 21/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 62.4062 - rmse: 7.8998 - val_loss: 61.1946 - val_rmse: 7.8227 - learning_rate: 0.0010
# Epoch 22/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 62.2880 - rmse: 7.8923 - val_loss: 61.3108 - val_rmse: 7.8301 - learning_rate: 0.0010
# Epoch 23/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 62.1401 - rmse: 7.8829 - val_loss: 61.2092 - val_rmse: 7.8236 - learning_rate: 0.0010
# Epoch 24/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 61.9583 - rmse: 7.8714 - val_loss: 60.7230 - val_rmse: 7.7925 - learning_rate: 0.0010
# Epoch 25/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 61.7715 - rmse: 7.8595 - val_loss: 60.4984 - val_rmse: 7.7781 - learning_rate: 0.0010
# Epoch 26/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 61.5611 - rmse: 7.8461 - val_loss: 60.3151 - val_rmse: 7.7663 - learning_rate: 0.0010
# Epoch 27/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 61.4664 - rmse: 7.8401 - val_loss: 60.6718 - val_rmse: 7.7892 - learning_rate: 0.0010
# Epoch 28/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 61.3141 - rmse: 7.8303 - val_loss: 60.9066 - val_rmse: 7.8043 - learning_rate: 0.0010
# Epoch 29/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 61.1006 - rmse: 7.8167 - val_loss: 60.1427 - val_rmse: 7.7552 - learning_rate: 0.0010
# Epoch 30/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 60.9464 - rmse: 7.8068 - val_loss: 59.8032 - val_rmse: 7.7333 - learning_rate: 0.0010
# Epoch 31/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 60.8732 - rmse: 7.8021 - val_loss: 59.9215 - val_rmse: 7.7409 - learning_rate: 0.0010
# Epoch 32/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 60.8829 - rmse: 7.8027 - val_loss: 60.2252 - val_rmse: 7.7605 - learning_rate: 0.0010
# Epoch 33/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 60.3255 - rmse: 7.7669 - val_loss: 60.0437 - val_rmse: 7.7488 - learning_rate: 0.0010
# Epoch 34/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 60.4030 - rmse: 7.7719 - val_loss: 59.9035 - val_rmse: 7.7397 - learning_rate: 0.0010
# Epoch 35/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 60.3752 - rmse: 7.7702 - val_loss: 59.8856 - val_rmse: 7.7386 - learning_rate: 0.0010
# Epoch 36/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 59.9744 - rmse: 7.7443 - val_loss: 59.6172 - val_rmse: 7.7212 - learning_rate: 5.0000e-04
# Epoch 37/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 60.0814 - rmse: 7.7512 - val_loss: 59.4940 - val_rmse: 7.7132 - learning_rate: 5.0000e-04
# Epoch 38/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 59.9028 - rmse: 7.7397 - val_loss: 59.3257 - val_rmse: 7.7023 - learning_rate: 5.0000e-04
# Epoch 39/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 59.5891 - rmse: 7.7194 - val_loss: 59.3838 - val_rmse: 7.7061 - learning_rate: 5.0000e-04
# Epoch 40/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 59.4065 - rmse: 7.7076 - val_loss: 59.2466 - val_rmse: 7.6972 - learning_rate: 5.0000e-04
# Epoch 41/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 59.4581 - rmse: 7.7109 - val_loss: 59.0640 - val_rmse: 7.6853 - learning_rate: 5.0000e-04
# Epoch 42/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 59.6100 - rmse: 7.7207 - val_loss: 59.0925 - val_rmse: 7.6872 - learning_rate: 5.0000e-04
# Epoch 43/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 59.4242 - rmse: 7.7087 - val_loss: 59.3288 - val_rmse: 7.7025 - learning_rate: 5.0000e-04
# Epoch 44/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 59.6211 - rmse: 7.7215 - val_loss: 59.2973 - val_rmse: 7.7005 - learning_rate: 5.0000e-04
# Epoch 45/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 59.6175 - rmse: 7.7212 - val_loss: 59.2072 - val_rmse: 7.6946 - learning_rate: 5.0000e-04
# Epoch 46/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 59.4261 - rmse: 7.7088 - val_loss: 59.0144 - val_rmse: 7.6821 - learning_rate: 5.0000e-04
# Epoch 47/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 59.1413 - rmse: 7.6903 - val_loss: 59.0722 - val_rmse: 7.6858 - learning_rate: 5.0000e-04
# Epoch 48/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 59.4111 - rmse: 7.7079 - val_loss: 59.0238 - val_rmse: 7.6827 - learning_rate: 5.0000e-04
# Epoch 49/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 59.3037 - rmse: 7.7009 - val_loss: 59.0752 - val_rmse: 7.6860 - learning_rate: 5.0000e-04
# Epoch 50/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 59.1250 - rmse: 7.6893 - val_loss: 58.9705 - val_rmse: 7.6792 - learning_rate: 5.0000e-04
# Epoch 51/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 59.0144 - rmse: 7.6821 - val_loss: 58.8653 - val_rmse: 7.6724 - learning_rate: 5.0000e-04
# Epoch 52/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 58.8836 - rmse: 7.6736 - val_loss: 59.0822 - val_rmse: 7.6865 - learning_rate: 5.0000e-04
# Epoch 53/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 59.2849 - rmse: 7.6997 - val_loss: 58.9079 - val_rmse: 7.6751 - learning_rate: 5.0000e-04
# Epoch 54/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 58.9153 - rmse: 7.6756 - val_loss: 58.7398 - val_rmse: 7.6642 - learning_rate: 5.0000e-04
# Epoch 55/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 59.0341 - rmse: 7.6834 - val_loss: 58.9422 - val_rmse: 7.6774 - learning_rate: 5.0000e-04
# Epoch 56/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 58.8829 - rmse: 7.6735 - val_loss: 58.6418 - val_rmse: 7.6578 - learning_rate: 5.0000e-04
# Epoch 57/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 58.8710 - rmse: 7.6727 - val_loss: 58.7351 - val_rmse: 7.6639 - learning_rate: 5.0000e-04
# Epoch 58/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 58.8153 - rmse: 7.6691 - val_loss: 58.9753 - val_rmse: 7.6795 - learning_rate: 5.0000e-04
# Epoch 59/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 58.6178 - rmse: 7.6562 - val_loss: 58.7689 - val_rmse: 7.6661 - learning_rate: 5.0000e-04
# Epoch 60/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 58.7045 - rmse: 7.6619 - val_loss: 58.7204 - val_rmse: 7.6629 - learning_rate: 5.0000e-04
# Epoch 61/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 58.6275 - rmse: 7.6569 - val_loss: 58.8796 - val_rmse: 7.6733 - learning_rate: 5.0000e-04
# Epoch 62/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 58.4198 - rmse: 7.6433 - val_loss: 58.5443 - val_rmse: 7.6514 - learning_rate: 2.5000e-04
# Epoch 63/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 58.4922 - rmse: 7.6480 - val_loss: 58.6563 - val_rmse: 7.6587 - learning_rate: 2.5000e-04
# Epoch 64/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 58.3539 - rmse: 7.6390 - val_loss: 58.5135 - val_rmse: 7.6494 - learning_rate: 2.5000e-04
# Epoch 65/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 58.1751 - rmse: 7.6273 - val_loss: 58.6839 - val_rmse: 7.6605 - learning_rate: 2.5000e-04
# Epoch 66/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 58.4832 - rmse: 7.6474 - val_loss: 58.5403 - val_rmse: 7.6512 - learning_rate: 2.5000e-04
# Epoch 67/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 58.2902 - rmse: 7.6348 - val_loss: 58.6156 - val_rmse: 7.6561 - learning_rate: 2.5000e-04
# Epoch 68/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 58.0901 - rmse: 7.6217 - val_loss: 58.4946 - val_rmse: 7.6482 - learning_rate: 2.5000e-04
# Epoch 69/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 58.3310 - rmse: 7.6375 - val_loss: 58.5193 - val_rmse: 7.6498 - learning_rate: 2.5000e-04
# Epoch 70/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 58.2806 - rmse: 7.6342 - val_loss: 58.4277 - val_rmse: 7.6438 - learning_rate: 2.5000e-04
# Epoch 71/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 58.0061 - rmse: 7.6162 - val_loss: 58.3830 - val_rmse: 7.6409 - learning_rate: 2.5000e-04
# Epoch 72/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 58.2086 - rmse: 7.6295 - val_loss: 58.5179 - val_rmse: 7.6497 - learning_rate: 2.5000e-04
# Epoch 73/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 58.3218 - rmse: 7.6369 - val_loss: 58.4370 - val_rmse: 7.6444 - learning_rate: 2.5000e-04
# Epoch 74/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 57.9906 - rmse: 7.6152 - val_loss: 58.3625 - val_rmse: 7.6395 - learning_rate: 2.5000e-04
# Epoch 75/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 57.9788 - rmse: 7.6144 - val_loss: 58.3787 - val_rmse: 7.6406 - learning_rate: 2.5000e-04
# Epoch 76/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 58.0381 - rmse: 7.6183 - val_loss: 58.3500 - val_rmse: 7.6387 - learning_rate: 2.5000e-04
# Epoch 77/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 57.9649 - rmse: 7.6135 - val_loss: 58.3117 - val_rmse: 7.6362 - learning_rate: 2.5000e-04
# Epoch 78/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 57.7395 - rmse: 7.5987 - val_loss: 58.3731 - val_rmse: 7.6402 - learning_rate: 2.5000e-04
# Epoch 79/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 57.9784 - rmse: 7.6144 - val_loss: 58.4117 - val_rmse: 7.6428 - learning_rate: 2.5000e-04
# Epoch 80/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 58.0497 - rmse: 7.6190 - val_loss: 58.4275 - val_rmse: 7.6438 - learning_rate: 2.5000e-04
# Epoch 81/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 57.9884 - rmse: 7.6150 - val_loss: 58.3908 - val_rmse: 7.6414 - learning_rate: 2.5000e-04
# Epoch 82/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 58.0066 - rmse: 7.6162 - val_loss: 58.3237 - val_rmse: 7.6370 - learning_rate: 2.5000e-04
# Epoch 83/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 57.8689 - rmse: 7.6072 - val_loss: 58.2583 - val_rmse: 7.6327 - learning_rate: 1.2500e-04
# Epoch 84/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 57.8361 - rmse: 7.6050 - val_loss: 58.1783 - val_rmse: 7.6275 - learning_rate: 1.2500e-04
# Epoch 85/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 57.6056 - rmse: 7.5898 - val_loss: 58.2266 - val_rmse: 7.6306 - learning_rate: 1.2500e-04
# Epoch 86/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 57.7193 - rmse: 7.5973 - val_loss: 58.2154 - val_rmse: 7.6299 - learning_rate: 1.2500e-04
# Epoch 87/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 57.7978 - rmse: 7.6025 - val_loss: 58.2111 - val_rmse: 7.6296 - learning_rate: 1.2500e-04
# Epoch 88/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 57.5972 - rmse: 7.5893 - val_loss: 58.1932 - val_rmse: 7.6284 - learning_rate: 1.2500e-04
# Epoch 89/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 57.7491 - rmse: 7.5993 - val_loss: 58.2822 - val_rmse: 7.6343 - learning_rate: 1.2500e-04
# Epoch 90/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 57.7323 - rmse: 7.5982 - val_loss: 58.2750 - val_rmse: 7.6338 - learning_rate: 6.2500e-05
# Epoch 91/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 57.7063 - rmse: 7.5965 - val_loss: 58.2665 - val_rmse: 7.6333 - learning_rate: 6.2500e-05
# Epoch 92/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 57.5723 - rmse: 7.5876 - val_loss: 58.2338 - val_rmse: 7.6311 - learning_rate: 6.2500e-05
# Epoch 93/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 57.5070 - rmse: 7.5833 - val_loss: 58.2476 - val_rmse: 7.6320 - learning_rate: 6.2500e-05
# Epoch 94/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 57.5958 - rmse: 7.5892 - val_loss: 58.2130 - val_rmse: 7.6297 - learning_rate: 6.2500e-05

# %%
# ============================================================
# 11) Evaluate + predict on test
# ============================================================
# model.evaluate returns [loss, rmse] because we compiled with metric rmse
eval_res = model.evaluate(test_inputs, yte, verbose=0)
print("Test evaluation:", dict(zip(model.metrics_names, eval_res)))

# Predict test set
pred_nn = model.predict(test_inputs, verbose=0).ravel()

# Compute RMSE using sklearn as well (double-check)
rmse_nn = root_mean_squared_error(np.asarray(y_test).ravel(), pred_nn)
print(f"Keras NN Test RMSE (sklearn): {rmse_nn:.4f}")
# Out:
# Test evaluation: {'loss': 59.545894622802734, 'compile_metrics': 7.7165985107421875}
# Keras NN Test RMSE (sklearn): 7.7166

# %%
# ============================================================
# 12) Create your comparison table (y_true vs NN_pred)
# ============================================================
df_compare = pd.DataFrame({
    "y_true": np.asarray(y_test).ravel(),
    "NN_pred": pred_nn
})

print(df_compare.head(20))
# Out:
#     y_true    NN_pred
# 0    -15.0 -14.837687
# 1     -2.0  -8.483032
# 2    -19.0 -21.661699
# 3    -17.0 -22.572496
# 4     -5.0  -8.321438
# 5     -3.0  -3.879128
# 6    -13.0 -11.847809
# 7    -19.0 -19.306744
# 8    -10.0 -14.152117
# 9    -20.0 -23.953321
# 10   -20.0 -16.407118
# 11    -7.0  -9.280128
# 12   -14.0 -13.793201
# 13    -8.0 -10.924683
# 14    -7.0  -9.150761
# 15   -19.0 -20.331820
# 16   -20.0 -19.554499
# 17    -5.0 -13.040726
# 18   -10.0  -9.528877
# 19   -20.0 -19.165087
